# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\Admin\Downloads\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
id(movies)
# Out:
# 1505866908400

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.1.3

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.3

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings',
       'BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer   Comedy            87               81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies.describe().transpose()
# Out:
#                  count         mean        std     min     25%     50%  \
# CriticRating     559.0    47.309481  26.413091     0.0    25.0    46.0
# AudienceRatings  559.0    58.744186  16.826887     0.0    47.0    58.0
# BudgetMillions   559.0    50.236136  48.731817     0.0    20.0    35.0
# Year             559.0  2009.152057   1.362632  2007.0  2008.0  2009.0
#
#                     75%     max
# CriticRating       70.0    97.0
# AudienceRatings    72.0    96.0
# BudgetMillions     65.0   300.0
# Year             2010.0  2011.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions
# count    559.000000       559.000000      559.000000
# mean      47.309481        58.744186       50.236136
# std       26.413091        16.826887       48.731817
# min        0.000000         0.000000        0.000000
# 25%       25.000000        47.000000       20.000000
# 50%       46.000000        58.000000       35.000000
# 75%       70.000000        72.000000       65.000000
# max       97.000000        96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data=movies, x ='CriticRating', y ='AudienceRatings', kind='hex')

# %%
j = sns.jointplot(data=movies, x ='CriticRating', y ='AudienceRatings', kind='scatter')

# %%
j = sns.jointplot(data=movies, x ='CriticRating', y ='AudienceRatings', kind='reg')

# %%
j = sns.jointplot(data=movies, x ='CriticRating', y ='AudienceRatings', kind='kde')

# %%
j = sns.jointplot(data=movies, x ='CriticRating', y ='AudienceRatings', kind='hist')

# %%
j = sns.jointplot(data=movies, x ='CriticRating', y ='AudienceRatings', kind='resid')

# %%
m1 = sns.distplot(movies.AudienceRatings)

# %%
m1 = sns.distplot(movies.CriticRating)

# %%
m1 = sns.displot(movies.AudienceRatings)

# %%
m1 = sns.displot(movies.CriticRating)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.CriticRating , bins=15)

# %%
sns.set_style('white')
m2 = sns.distplot(movies.CriticRating , bins=15)

# %%
sns.set_style('dark')
h1 = plt.hist(movies.AudienceRatings , bins=20)

# %%
sns.set_style('white')
h1 = plt.hist(movies.CriticRating , bins=15)

# %%
h1 = plt.hist(movies.BudgetMillions)

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings', fit_reg=False)

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings', fit_reg=True, hue='Genre')

# %%
ax = plt.subplots(3,3, figsize=(10,8))

# %%
ax = plt.subplots(1,3, figsize=(13,3))

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y='AudienceRatings')

# %%
#violin plot
z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# Creating a Facet grid
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')  #kind of subplots

# %%
plt.scatter(movies.CriticRating,movies.AudienceRatings)

# %%
g =sns.FacetGrid(movies, row = 'Genre', col='Year', hue='Genre')
g= g.map(plt.scatter, 'CriticRating','AudienceRatings')   #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid(movies, row = 'Genre', col='Year', hue='Genre')
g= g.map(plt.hist, 'BudgetMillions')   #histogram are mapped in facetgrid
