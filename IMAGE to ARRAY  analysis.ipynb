# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
image = Image.open(r'C:\Users\Admin\Desktop\peacock.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=670x419>

# %%
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
peacock=np.asarray(image)
peacock
# Out:
# array([[[111, 118, 128],
#         [ 69,  76,  86],
#         [ 69,  76,  86],
#         ...,
#         [ 16,  19,  34],
#         [ 13,  16,  31],
#         [ 18,  21,  36]],
#
#        [[ 57,  64,  74],
#         [104, 111, 121],
#         [129, 136, 146],
#         ...,
#         [ 99, 102, 117],
#         [103, 106, 121],
#         [114, 117, 132]],
#
#        [[ 99, 106, 116],
#         [ 94, 101, 111],
#         [101, 108, 118],
#         ...,
#         [ 91,  94, 109],
#         [ 92,  95, 110],
#         [ 67,  70,  85]],
#
#        ...,
#
#        [[ 28,  40,  20],
#         [ 30,  41,  24],
#         [ 29,  40,  23],
#         ...,
#         [ 33,  34,  39],
#         [ 41,  42,  47],
#         [ 44,  45,  50]],
#
#        [[ 28,  40,  20],
#         [ 30,  41,  24],
#         [ 29,  40,  23],
#         ...,
#         [ 33,  34,  39],
#         [ 41,  42,  47],
#         [ 44,  45,  50]],
#
#        [[ 28,  40,  20],
#         [ 30,  41,  24],
#         [ 29,  40,  23],
# ...

# %%
plt.imshow(image)
plt.show()

# %%
peacock.shape
# Out:
# (419, 670, 3)
